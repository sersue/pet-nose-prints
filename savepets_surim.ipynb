# %% [markdown]
# <a href="https://colab.research.google.com/github/sersue/pet-nose-prints/blob/master/savepets_surim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
from IPython.display import Image
image = Image('/gdrive/My Drive/001.png')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('/gdrive/My Drive/001.png',cv2.IMREAD_GRAYSCALE) #흑백화
kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])

image_sharp = cv2.filter2D(image,-1,kernel) # 선명하게



plt.imshow(image_sharp,cmap="gray"),plt.axis("off")
plt.show()

# %%
# image threshold -  흑백 이미지를 이진 이미지로 변환하는 방ㅂ버이다.
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
origin_img = cv2.imread('/gdrive/My Drive/001.png', 0) # gray scale
#origin_img = origin_img / 255
 
# basic threshold
threshold, mask = cv2.threshold(origin_img, 200, 1, cv2.THRESH_BINARY)
print('값: ', threshold)
 
# adapt threshold
adapt_mask = cv2.adaptiveThreshold(origin_img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 11, 10)
 
# visualization
plt.figure(figsize=(10,3))
plt.subplot(131)
plt.axis('off')
plt.title('origin_img')
plt.imshow(origin_img, cmap='gray')
plt.subplot(132)
plt.axis('off')
plt.title('binary threshold')
plt.imshow(mask, cmap='gray')
plt.subplot(133)
plt.axis('off')
plt.title('adaptive threshold')
plt.imshow(adapt_mask, cmap='gray')
plt.tight_layout()
plt.show()
# Out:
# 값:  200.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math
 
origin_img = cv2.imread('/gdrive/My Drive/001.png', 0).astype(np.float32) # gray scale
origin_img = origin_img / 255
 
# Garbor filter form
kernel = cv2.getGaborKernel((21,21), 5, 1, 10, 1, 0, cv2.CV_32F)
kernel /= math.sqrt((kernel * kernel).sum())
 
filtered = cv2.filter2D(origin_img, -1, kernel)
 
plt.figure(figsize=(8,3))
plt.subplot(131)
plt.axis('off')
plt.title('origin_img')
plt.imshow(origin_img, cmap='gray')
plt.subplot(132)
plt.axis('off')
plt.imshow(kernel, cmap='gray')
plt.title('kernel')
plt.subplot(133)
plt.axis('off')
plt.title('filtered')
plt.imshow(filtered, cmap='gray')
plt.tight_layout()
plt.show()

# %%
# !git clone https://github.com/Antoninj/biometrics-project.git
# Out:
# Cloning into 'biometrics-project'...
# remote: Enumerating objects: 1554, done.
# remote: Total 1554 (delta 0), reused 0 (delta 0), pack-reused 1554
# Receiving objects: 100% (1554/1554), 116.94 MiB | 32.92 MiB/s, done.
# Resolving deltas: 100% (160/160), done.
# Checking out files: 100% (1255/1255), done.

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('/gdrive/My Drive/002.png',cv2.IMREAD_GRAYSCALE) #흑백화
kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])

image_sharp = cv2.filter2D(image,-1,kernel) # 선명하게



plt.imshow(image_sharp,cmap="gray"),plt.axis("off")
plt.show()

# %%
# !pwd
# !git clone https://github.com/Ekberjan/Fingerprint_Image_Enhancement.git
# Out:
# /content
# Cloning into 'Fingerprint_Image_Enhancement'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 254 (delta 55), reused 84 (delta 38), pack-reused 145
# Receiving objects: 100% (254/254), 377.73 KiB | 2.04 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
# !pwd
# !mkdir -p build
# %cd build
# Out:
# /content/Fingerprint_Image_Enhancement
# /content/Fingerprint_Image_Enhancement/build

# %%
# !git submodule update --init --recursive
# Out:
# Submodule 'pybind11' (https://github.com/pybind/pybind11/) registered for path 'pybind11'
# Cloning into '/content/Fingerprint_Image_Enhancement/pybind11'...
# Submodule path 'pybind11': checked out 'c4a8b5bb9140cdc8c214044d41e2593986f875d0'

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing fingerprint.egg-info/PKG-INFO
# writing dependency_links to fingerprint.egg-info/dependency_links.txt
# writing top-level names to fingerprint.egg-info/top_level.txt
# writing manifest file 'fingerprint.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# -- pybind11 v2.6.0
# -- Found PythonInterp: /usr/bin/python3 (found version "3.6.9")
# -- Found PythonLibs: /usr/lib/x86_64-linux-gnu/libpython3.6m.so
# -- Performing Test HAS_FLTO
# -- Performing Test HAS_FLTO - Success
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/Fingerprint_Image_Enhancement/build/temp.linux-x86_64-3.6
# Scanning dependencies of target fingerprint
# Scanning dependencies of target fingerPrint
# [ 14%] Building CXX object src/CMakeFiles/fingerPrint.dir/fpenhancement.cpp.o
# ...

# %%
# !cmake ..
# Out:
# -- pybind11 v2.6.0
# -- Found PythonInterp: /usr/bin/python3.6 (found version "3.6.9")
# -- Found PythonLibs: /usr/lib/x86_64-linux-gnu/libpython3.6m.so
# -- Performing Test HAS_FLTO
# -- Performing Test HAS_FLTO - Success
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/Fingerprint_Image_Enhancement/build

# %%
# !make
# Out:
# Scanning dependencies of target fingerprint
# [ 14%] Building CXX object CMakeFiles/fingerprint.dir/src/fpenhancement.cpp.o
# [ 28%] Building CXX object CMakeFiles/fingerprint.dir/src/binders.cpp.o
# [ 42%] Building CXX object CMakeFiles/fingerprint.dir/src/ndarray_converter.cpp.o
# /content/Fingerprint_Image_Enhancement/src/ndarray_converter.cpp:21:10: fatal error: numpy/ndarrayobject.h: No such file or directory
#  #include <numpy/ndarrayobject.h>
#           ^~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# CMakeFiles/fingerprint.dir/build.make:88: recipe for target 'CMakeFiles/fingerprint.dir/src/ndarray_converter.cpp.o' failed
# make[2]: *** [CMakeFiles/fingerprint.dir/src/ndarray_converter.cpp.o] Error 1
# CMakeFiles/Makefile2:72: recipe for target 'CMakeFiles/fingerprint.dir/all' failed
# make[1]: *** [CMakeFiles/fingerprint.dir/all] Error 2
# Makefile:83: recipe for target 'all' failed
# make: *** [all] Error 2
